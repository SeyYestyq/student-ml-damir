# %%
import numpy as np

#задание 1
massive=np.array([1,7,10,12,14])
print (massive)



#задание 2
two_massive=np.array([[1,2,3],[4,5,6]])
print (two_massive)

# использованием функций `zeros`, `ones`, `arange`
massive_zeros=np.zeros((2,5))
print (massive_zeros)

arr_massive=np.arange(10,25,0.5)
print (arr_massive)
 
#задание 3
print (two_massive.shape)
print (two_massive.dtype)

#задание 4
indx_massive=massive[2]
print (indx_massive) 
slice_massive=massive[1:4]
print (slice_massive)

#задание 5
# Векторное умножение элементов
massive_one=np.array([10,20,30,40,50])
massibe_two=np.array([1,2,3,4,5])
sum_massive=massive_one*massibe_two
print (sum_massive)
#вычисление средней величины
mean_massive=massive_one.mean()
print (mean_massive)
# Out:
# Для выполнения ячеек с "Python 3.12.11" требуется пакет ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Создать среду Python</a> с необходимыми пакетами.
